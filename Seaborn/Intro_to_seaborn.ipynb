# %%
import seaborn as sns
import numpy as np

# %%
sns.set_theme(style="darkgrid")

# %%
x = np.array([1, 4, 7, 9, 24, 64, 34, 62, 21, 46, 89, 90])

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.84147098, -0.7568025 ,  0.6569866 ,  0.41211849, -0.90557836,
#         0.92002604,  0.52908269, -0.7391807 ,  0.83665564,  0.90178835,
#         0.86006941,  0.89399666])

# %%
sns.lineplot(x=x, y=y)
# Out:
# <Axes: >
