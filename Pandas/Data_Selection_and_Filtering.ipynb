# %%
import pandas as pd

# %%
df = pd.read_csv("bollywood.csv")

# %%
df
# Out:
#             Actor                   Film  Year       Genre  \
# 0  Shah Rukh Khan                Pathaan  2023      Action
# 1      Aamir Khan                 Dangal  2016   Biography
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
#
#    BoxOffice (INR Crore)  IMDb  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0                   1050   7.0         NaN         NaN         NaN         NaN
# 1                   2100   8.4         NaN         NaN         NaN         NaN
# 2                    970   8.0         NaN         NaN         NaN         NaN
# 3                    586   7.6         NaN         NaN         NaN         NaN
# 4                    475   6.5         NaN         NaN         NaN         NaN
# 5                    238   7.9         NaN         NaN         NaN         NaN
# 6                    367   7.6         NaN         NaN         NaN         NaN
# 7                    294   6.1         NaN         NaN         NaN         NaN
# 8                    206   6.1         NaN         NaN         NaN         NaN

# %%
# Remove NaN column from my data 

df.dropna(axis=1, how='all', inplace=True)  

# If you want to remove columns with any NaN values use

# how='any'

# %%
df
# Out:
#             Actor                   Film  Year       Genre  \
# 0  Shah Rukh Khan                Pathaan  2023      Action
# 1      Aamir Khan                 Dangal  2016   Biography
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
#
#    BoxOffice (INR Crore)  IMDb
# 0                   1050   7.0
# 1                   2100   8.4
# 2                    970   8.0
# 3                    586   7.6
# 4                    475   6.5
# 5                    238   7.9
# 6                    367   7.6
# 7                    294   6.1
# 8                    206   6.1

# %%
# Extract Specific Column

df['Actor']        # Single column (as Series)
# Out:
# 0    Shah Rukh Khan
# 1        Aamir Khan
# 2       Salman Khan
# 3     Ranbir Kapoor
# 4    Hrithik Roshan
# 5     Ranveer Singh
# 6        Ajay Devgn
# 7      Akshay Kumar
# 8      Varun Dhawan
# Name: Actor, dtype: object

# %%
type(df['Actor'])
# Out:
# pandas.core.series.Series

# %%
# This is only copy if you want to change in main data use inplace=True

df[["Actor","Film"]]          # Multiple columns (as DataFrame)
# Out:
#             Actor                   Film
# 0  Shah Rukh Khan                Pathaan
# 1      Aamir Khan                 Dangal
# 2     Salman Khan      Bajrangi Bhaijaan
# 3   Ranbir Kapoor                  Sanju
# 4  Hrithik Roshan                    War
# 5   Ranveer Singh              Gully Boy
# 6      Ajay Devgn                Tanhaji
# 7    Akshay Kumar           Sooryavanshi
# 8    Varun Dhawan  Badrinath Ki Dulhania

# %%
type(df[["Actor","Film"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#             Actor                   Film  Year       Genre  \
# 0  Shah Rukh Khan                Pathaan  2023      Action
# 1      Aamir Khan                 Dangal  2016   Biography
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
#
#    BoxOffice (INR Crore)  IMDb
# 0                   1050   7.0
# 1                   2100   8.4
# 2                    970   8.0
# 3                    586   7.6
# 4                    475   6.5
# 5                    238   7.9
# 6                    367   7.6
# 7                    294   6.1
# 8                    206   6.1

# %%
# Selecting Rows by Index

# First row (by label)

df.loc[0]          # this is find your data by index
# Out:
# Actor                    Shah Rukh Khan
# Film                            Pathaan
# Year                               2023
# Genre                            Action
# BoxOffice (INR Crore)              1050
# IMDb                                7.0
# Name: 0, dtype: object

# %%
# First row (by position) -> According to Index

df.iloc[0]      # Same result as that of loc what differnet?

# iloc is useful when we change the row label and now we try with loc we can't pass number we need to give the label of the row or columns but we do this with iloc by using index
# Out:
# Actor                    Shah Rukh Khan
# Film                            Pathaan
# Year                               2023
# Genre                            Action
# BoxOffice (INR Crore)              1050
# IMDb                                7.0
# Name: 0, dtype: object

# %%
df.loc[2,"Film"]          # Use label
# Out:
# 'Bajrangi Bhaijaan'

# %%
df.iloc[2,1]       # Use Index
# Out:
# 'Bajrangi Bhaijaan'

# %% [markdown]
# # Slicing

# %%
# Slicing using loc

# Note :- 4 is inclusive in loc
# Note :- This slicing is according to label

df.loc[0:4, "Actor":"Genre"]
# Out:
#             Actor               Film  Year      Genre
# 0  Shah Rukh Khan            Pathaan  2023     Action
# 1      Aamir Khan             Dangal  2016  Biography
# 2     Salman Khan  Bajrangi Bhaijaan  2015      Drama
# 3   Ranbir Kapoor              Sanju  2018  Biography
# 4  Hrithik Roshan                War  2019     Action

# %%
# Slicing using loc (Giving list of columns)

df.loc[0:4, ["Actor","IMDb","BoxOffice (INR Crore)","Genre"]]  # New View is according to this order of loc
# Out:
#             Actor  IMDb  BoxOffice (INR Crore)      Genre
# 0  Shah Rukh Khan   7.0                   1050     Action
# 1      Aamir Khan   8.4                   2100  Biography
# 2     Salman Khan   8.0                    970      Drama
# 3   Ranbir Kapoor   7.6                    586  Biography
# 4  Hrithik Roshan   6.5                    475     Action

# %%
# Slicing using iloc with index

# Note :- 4 is exclusive in iloc

df.iloc[0:4 , 0: 4]
# Out:
#             Actor               Film  Year      Genre
# 0  Shah Rukh Khan            Pathaan  2023     Action
# 1      Aamir Khan             Dangal  2016  Biography
# 2     Salman Khan  Bajrangi Bhaijaan  2015      Drama
# 3   Ranbir Kapoor              Sanju  2018  Biography

# %%
# Fastest Method to access one particular element at and iat (loc and iloc is not as faster as that of at and iat)

# Use only when you want to access one particular element

df.at[8,"Film"]
# Out:
# 'Badrinath Ki Dulhania'

# %%
df.iat[4,1]
# Out:
# 'War'

# %% [markdown]
# # Filtering

# %%
# Filtering and extract whole data frame

df[df["IMDb"] > 7.8]
# Out:
#            Actor               Film  Year      Genre  BoxOffice (INR Crore)  \
# 1     Aamir Khan             Dangal  2016  Biography                   2100
# 2    Salman Khan  Bajrangi Bhaijaan  2015      Drama                    970
# 5  Ranveer Singh          Gully Boy  2019    Musical                    238
#
#    IMDb
# 1   8.4
# 2   8.0
# 5   7.9

# %%
# Filtering and extract specific column (Use Chaining)

df[df["IMDb"] < 7 ]["Film"]
# Out:
# 4                      War
# 7             Sooryavanshi
# 8    Badrinath Ki Dulhania
# Name: Film, dtype: object

# %%
# Now i want that new film will show after 2019 with BoxOffice greater 500 Cr.

df[(df["Year"] >= 2018) & (df["BoxOffice (INR Crore)"] > 500)]["Film"]
# Out:
# 0    Pathaan
# 3      Sanju
# Name: Film, dtype: object

# %%
# Best funtion for easy filter df.query()

df.query("Year >= 2018")
# Out:
#             Actor          Film  Year       Genre  BoxOffice (INR Crore)  IMDb
# 0  Shah Rukh Khan       Pathaan  2023      Action                   1050   7.0
# 3   Ranbir Kapoor         Sanju  2018   Biography                    586   7.6
# 4  Hrithik Roshan           War  2019      Action                    475   6.5
# 5   Ranveer Singh     Gully Boy  2019     Musical                    238   7.9
# 6      Ajay Devgn       Tanhaji  2020  Historical                    367   7.6
# 7    Akshay Kumar  Sooryavanshi  2021      Action                    294   6.1

# %%
# Not use and, or symbol write full keyword to filter the data

df.query("Year == 2019 or Genre == 'Biography'")
# Out:
#             Actor       Film  Year      Genre  BoxOffice (INR Crore)  IMDb
# 1      Aamir Khan     Dangal  2016  Biography                   2100   8.4
# 3   Ranbir Kapoor      Sanju  2018  Biography                    586   7.6
# 4  Hrithik Roshan        War  2019     Action                    475   6.5
# 5   Ranveer Singh  Gully Boy  2019    Musical                    238   7.9

# %%
# Use Backtick when you columns name is included with special character

df.query("`BoxOffice (INR Crore)` == 238")
# Out:
#            Actor       Film  Year    Genre  BoxOffice (INR Crore)  IMDb
# 5  Ranveer Singh  Gully Boy  2019  Musical                    238   7.9

# %%
my_bday_year = 2017
# Use @ when you want to use variable for your filtering

df.query("Year == @my_bday_year")
# Out:
#           Actor                   Film  Year    Genre  BoxOffice (INR Crore)  \
# 8  Varun Dhawan  Badrinath Ki Dulhania  2017  Romance                    206
#
#    IMDb
# 8   6.1

# %%
# Chained Comparision

df.query("500 < `BoxOffice (INR Crore)` < 1000")
# Out:
#            Actor               Film  Year      Genre  BoxOffice (INR Crore)  \
# 2    Salman Khan  Bajrangi Bhaijaan  2015      Drama                    970
# 3  Ranbir Kapoor              Sanju  2018  Biography                    586
#
#    IMDb
# 2   8.0
# 3   7.6

# %%
# Most of the funtion return copy but you can use copy funtion to ensure that we extract a copy not the view

df2 = df[["Actor","Film"]].copy()

# By default it give copy but by using copy fuction it give guarantee that it is a copy not view

# %%
df2
# Out:
#             Actor                   Film
# 0  Shah Rukh Khan                Pathaan
# 1      Aamir Khan                 Dangal
# 2     Salman Khan      Bajrangi Bhaijaan
# 3   Ranbir Kapoor                  Sanju
# 4  Hrithik Roshan                    War
# 5   Ranveer Singh              Gully Boy
# 6      Ajay Devgn                Tanhaji
# 7    Akshay Kumar           Sooryavanshi
# 8    Varun Dhawan  Badrinath Ki Dulhania

# %%
df2.loc[0,"Actor"] = "Dushyant"

# %%
# df2 completely independent from df

df2
# Out:
#             Actor                   Film
# 0        Dushyant                Pathaan
# 1      Aamir Khan                 Dangal
# 2     Salman Khan      Bajrangi Bhaijaan
# 3   Ranbir Kapoor                  Sanju
# 4  Hrithik Roshan                    War
# 5   Ranveer Singh              Gully Boy
# 6      Ajay Devgn                Tanhaji
# 7    Akshay Kumar           Sooryavanshi
# 8    Varun Dhawan  Badrinath Ki Dulhania

# %%
df
# Out:
#             Actor                   Film  Year       Genre  \
# 0  Shah Rukh Khan                Pathaan  2023      Action
# 1      Aamir Khan                 Dangal  2016   Biography
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
#
#    BoxOffice (INR Crore)  IMDb
# 0                   1050   7.0
# 1                   2100   8.4
# 2                    970   8.0
# 3                    586   7.6
# 4                    475   6.5
# 5                    238   7.9
# 6                    367   7.6
# 7                    294   6.1
# 8                    206   6.1
