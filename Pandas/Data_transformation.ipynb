# %%
import pandas as pd

# %%
df = pd.read_csv("bollywood.csv")

# %%
df
# Out:
#             Actor                   Film  Year       Genre  \
# 0  Shah Rukh Khan                Pathaan  2023      Action
# 1      Aamir Khan                 Dangal  2016   Biography
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
#
#    BoxOffice (INR Crore)  IMDb  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0                   1050   7.0         NaN         NaN         NaN         NaN
# 1                   2100   8.4         NaN         NaN         NaN         NaN
# 2                    970   8.0         NaN         NaN         NaN         NaN
# 3                    586   7.6         NaN         NaN         NaN         NaN
# 4                    475   6.5         NaN         NaN         NaN         NaN
# 5                    238   7.9         NaN         NaN         NaN         NaN
# 6                    367   7.6         NaN         NaN         NaN         NaN
# 7                    294   6.1         NaN         NaN         NaN         NaN
# 8                    206   6.1         NaN         NaN         NaN         NaN

# %%
df.dropna(axis=1, how="all",inplace=True)

# %%
df
# Out:
#             Actor                   Film  Year       Genre  \
# 0  Shah Rukh Khan                Pathaan  2023      Action
# 1      Aamir Khan                 Dangal  2016   Biography
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
#
#    BoxOffice (INR Crore)  IMDb
# 0                   1050   7.0
# 1                   2100   8.4
# 2                    970   8.0
# 3                    586   7.6
# 4                    475   6.5
# 5                    238   7.9
# 6                    367   7.6
# 7                    294   6.1
# 8                    206   6.1

# %%
# Assending order

df.sort_values("Year")
# Out:
#             Actor                   Film  Year       Genre  \
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 1      Aamir Khan                 Dangal  2016   Biography
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 4  Hrithik Roshan                    War  2019      Action
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 0  Shah Rukh Khan                Pathaan  2023      Action
#
#    BoxOffice (INR Crore)  IMDb
# 2                    970   8.0
# 1                   2100   8.4
# 8                    206   6.1
# 3                    586   7.6
# 5                    238   7.9
# 4                    475   6.5
# 6                    367   7.6
# 7                    294   6.1
# 0                   1050   7.0

# %%
# Decending Order

df.sort_values("Year",ascending=False)

# Recent film at top
# Out:
#             Actor                   Film  Year       Genre  \
# 0  Shah Rukh Khan                Pathaan  2023      Action
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
# 1      Aamir Khan                 Dangal  2016   Biography
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
#
#    BoxOffice (INR Crore)  IMDb
# 0                   1050   7.0
# 7                    294   6.1
# 6                    367   7.6
# 4                    475   6.5
# 5                    238   7.9
# 3                    586   7.6
# 8                    206   6.1
# 1                   2100   8.4
# 2                    970   8.0

# %%
# Now i want that if the year will tie then sort according to IMDb

df.sort_values(["Year", "IMDb"])
# Out:
#             Actor                   Film  Year       Genre  \
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 1      Aamir Khan                 Dangal  2016   Biography
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 0  Shah Rukh Khan                Pathaan  2023      Action
#
#    BoxOffice (INR Crore)  IMDb
# 2                    970   8.0
# 1                   2100   8.4
# 8                    206   6.1
# 3                    586   7.6
# 4                    475   6.5
# 5                    238   7.9
# 6                    367   7.6
# 7                    294   6.1
# 0                   1050   7.0

# %%
# Now I want that year come in ascending and imdb come in decending

df.sort_values(["Year", "IMDb"], ascending=[True, False])
# Out:
#             Actor                   Film  Year       Genre  \
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 1      Aamir Khan                 Dangal  2016   Biography
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 4  Hrithik Roshan                    War  2019      Action
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 0  Shah Rukh Khan                Pathaan  2023      Action
#
#    BoxOffice (INR Crore)  IMDb
# 2                    970   8.0
# 1                   2100   8.4
# 8                    206   6.1
# 3                    586   7.6
# 5                    238   7.9
# 4                    475   6.5
# 6                    367   7.6
# 7                    294   6.1
# 0                   1050   7.0

# %%
# Now we see how reset the index 

df2 = df.sort_values(["Year", "IMDb"]).copy()

# %%
df3 = df2.copy()

# %%
df3
# Out:
#             Actor                   Film  Year       Genre  \
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 1      Aamir Khan                 Dangal  2016   Biography
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 0  Shah Rukh Khan                Pathaan  2023      Action
#
#    BoxOffice (INR Crore)  IMDb
# 2                    970   8.0
# 1                   2100   8.4
# 8                    206   6.1
# 3                    586   7.6
# 4                    475   6.5
# 5                    238   7.9
# 6                    367   7.6
# 7                    294   6.1
# 0                   1050   7.0

# %%
df2
# Out:
#             Actor                   Film  Year       Genre  \
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 1      Aamir Khan                 Dangal  2016   Biography
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 0  Shah Rukh Khan                Pathaan  2023      Action
#
#    BoxOffice (INR Crore)  IMDb
# 2                    970   8.0
# 1                   2100   8.4
# 8                    206   6.1
# 3                    586   7.6
# 4                    475   6.5
# 5                    238   7.9
# 6                    367   7.6
# 7                    294   6.1
# 0                   1050   7.0

# %%
# df2 is jumbled data 

df2.reset_index()
# Out:
#    index           Actor                   Film  Year       Genre  \
# 0      2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 1      1      Aamir Khan                 Dangal  2016   Biography
# 2      8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
# 3      3   Ranbir Kapoor                  Sanju  2018   Biography
# 4      4  Hrithik Roshan                    War  2019      Action
# 5      5   Ranveer Singh              Gully Boy  2019     Musical
# 6      6      Ajay Devgn                Tanhaji  2020  Historical
# 7      7    Akshay Kumar           Sooryavanshi  2021      Action
# 8      0  Shah Rukh Khan                Pathaan  2023      Action
#
#    BoxOffice (INR Crore)  IMDb
# 0                    970   8.0
# 1                   2100   8.4
# 2                    206   6.1
# 3                    586   7.6
# 4                    475   6.5
# 5                    238   7.9
# 6                    367   7.6
# 7                    294   6.1
# 8                   1050   7.0

# %%
# Now it come with new column index but i don't need to do this use drop attribute

df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#             Actor                   Film  Year       Genre  \
# 0     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 1      Aamir Khan                 Dangal  2016   Biography
# 2    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 8  Shah Rukh Khan                Pathaan  2023      Action
#
#    BoxOffice (INR Crore)  IMDb
# 0                    970   8.0
# 1                   2100   8.4
# 2                    206   6.1
# 3                    586   7.6
# 4                    475   6.5
# 5                    238   7.9
# 6                    367   7.6
# 7                    294   6.1
# 8                   1050   7.0

# %%
# Use of sort_index()
df3
# Out:
#             Actor                   Film  Year       Genre  \
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 1      Aamir Khan                 Dangal  2016   Biography
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 0  Shah Rukh Khan                Pathaan  2023      Action
#
#    BoxOffice (INR Crore)  IMDb
# 2                    970   8.0
# 1                   2100   8.4
# 8                    206   6.1
# 3                    586   7.6
# 4                    475   6.5
# 5                    238   7.9
# 6                    367   7.6
# 7                    294   6.1
# 0                   1050   7.0

# %%
# In the df3 index is unsorted and year is sorted now i use sort_index() fucn

df3.sort_index(inplace=True)

# Sort the index in correct order

# %%
df3
# Out:
#             Actor                   Film  Year       Genre  \
# 0  Shah Rukh Khan                Pathaan  2023      Action
# 1      Aamir Khan                 Dangal  2016   Biography
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
#
#    BoxOffice (INR Crore)  IMDb
# 0                   1050   7.0
# 1                   2100   8.4
# 2                    970   8.0
# 3                    586   7.6
# 4                    475   6.5
# 5                    238   7.9
# 6                    367   7.6
# 7                    294   6.1
# 8                    206   6.1

# %%
# Ranking for df3 according to IMDb

# df3["Rank"] = df3["IMDb"].rank().astype("int32")

# or
# Make rank integer by dense

df3["Rank"] = df3["IMDb"].rank(method="dense").astype("int32")

# %%
df3
# Out:
#             Actor                   Film  Year       Genre  \
# 0  Shah Rukh Khan                Pathaan  2023      Action
# 1      Aamir Khan                 Dangal  2016   Biography
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
#
#    BoxOffice (INR Crore)  IMDb  Rank
# 0                   1050   7.0     3
# 1                   2100   8.4     7
# 2                    970   8.0     6
# 3                    586   7.6     4
# 4                    475   6.5     2
# 5                    238   7.9     5
# 6                    367   7.6     4
# 7                    294   6.1     1
# 8                    206   6.1     1

# %%
# It will give rank according to small one i want to larger one

df3["Ran"] = df3["IMDb"].rank(ascending=False)

# %%
df3
# Out:
#             Actor                   Film  Year       Genre  \
# 0  Shah Rukh Khan                Pathaan  2023      Action
# 1      Aamir Khan                 Dangal  2016   Biography
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
#
#    BoxOffice (INR Crore)  IMDb  Rank  Ran
# 0                   1050   7.0     3  6.0
# 1                   2100   8.4     7  1.0
# 2                    970   8.0     6  2.0
# 3                    586   7.6     4  4.5
# 4                    475   6.5     2  7.0
# 5                    238   7.9     5  3.0
# 6                    367   7.6     4  4.5
# 7                    294   6.1     1  8.5
# 8                    206   6.1     1  8.5

# %%
# Change the order of your column
# Reorder

df3 = df3[["Rank","Ran","BoxOffice (INR Crore)","IMDb","Film","Year"]]

# %%
df3
# Out:
#    Rank  Ran  BoxOffice (INR Crore)  IMDb                   Film  Year
# 0     3  6.0                   1050   7.0                Pathaan  2023
# 1     7  1.0                   2100   8.4                 Dangal  2016
# 2     6  2.0                    970   8.0      Bajrangi Bhaijaan  2015
# 3     4  4.5                    586   7.6                  Sanju  2018
# 4     2  7.0                    475   6.5                    War  2019
# 5     5  3.0                    238   7.9              Gully Boy  2019
# 6     4  4.5                    367   7.6                Tanhaji  2020
# 7     1  8.5                    294   6.1           Sooryavanshi  2021
# 8     1  8.5                    206   6.1  Badrinath Ki Dulhania  2017

# %%
# Rename the column Ran to Rank Decending

df3.rename(columns={"Ran": "Rank Descending"}, inplace=True)
# Out:
# /tmp/ipykernel_9730/2645608057.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.rename(columns={"Ran": "Rank Descending"}, inplace=True)

# %%
df3
# Out:
#    Rank  Rank Descending  BoxOffice (INR Crore)  IMDb                   Film  \
# 0     3              6.0                   1050   7.0                Pathaan
# 1     7              1.0                   2100   8.4                 Dangal
# 2     6              2.0                    970   8.0      Bajrangi Bhaijaan
# 3     4              4.5                    586   7.6                  Sanju
# 4     2              7.0                    475   6.5                    War
# 5     5              3.0                    238   7.9              Gully Boy
# 6     4              4.5                    367   7.6                Tanhaji
# 7     1              8.5                    294   6.1           Sooryavanshi
# 8     1              8.5                    206   6.1  Badrinath Ki Dulhania
#
#    Year
# 0  2023
# 1  2016
# 2  2015
# 3  2018
# 4  2019
# 5  2019
# 6  2020
# 7  2021
# 8  2017

# %%
# Rename the row index

df3.rename(index={0: "row1", 1: "row2"}, inplace=True)
# Out:
# /tmp/ipykernel_9730/1429628043.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.rename(index={0: "row1", 1: "row2"}, inplace=True)

# %%
df3
# Out:
#       Rank  Rank Descending  BoxOffice (INR Crore)  IMDb  \
# row1     3              6.0                   1050   7.0
# row2     7              1.0                   2100   8.4
# 2        6              2.0                    970   8.0
# 3        4              4.5                    586   7.6
# 4        2              7.0                    475   6.5
# 5        5              3.0                    238   7.9
# 6        4              4.5                    367   7.6
# 7        1              8.5                    294   6.1
# 8        1              8.5                    206   6.1
#
#                        Film  Year
# row1                Pathaan  2023
# row2                 Dangal  2016
# 2         Bajrangi Bhaijaan  2015
# 3                     Sanju  2018
# 4                       War  2019
# 5                 Gully Boy  2019
# 6                   Tanhaji  2020
# 7              Sooryavanshi  2021
# 8     Badrinath Ki Dulhania  2017

# %%
# Rename all the column

df3.columns = ["R1", "R2", "Box","Db","Movie","DOY"]

# %%
df3
# Out:
#       R1   R2   Box   Db                  Movie   DOY
# row1   3  6.0  1050  7.0                Pathaan  2023
# row2   7  1.0  2100  8.4                 Dangal  2016
# 2      6  2.0   970  8.0      Bajrangi Bhaijaan  2015
# 3      4  4.5   586  7.6                  Sanju  2018
# 4      2  7.0   475  6.5                    War  2019
# 5      5  3.0   238  7.9              Gully Boy  2019
# 6      4  4.5   367  7.6                Tanhaji  2020
# 7      1  8.5   294  6.1           Sooryavanshi  2021
# 8      1  8.5   206  6.1  Badrinath Ki Dulhania  2017

# %%
# You can also move one column to the front

cols = ["Movie"] + [col for col in df3.columns if col != "Movie"]
df3 = df3[cols]

# %%
df3
# Out:
#                       Movie  R1   R2   Box   Db   DOY
# row1                Pathaan   3  6.0  1050  7.0  2023
# row2                 Dangal   7  1.0  2100  8.4  2016
# 2         Bajrangi Bhaijaan   6  2.0   970  8.0  2015
# 3                     Sanju   4  4.5   586  7.6  2018
# 4                       War   2  7.0   475  6.5  2019
# 5                 Gully Boy   5  3.0   238  7.9  2019
# 6                   Tanhaji   4  4.5   367  7.6  2020
# 7              Sooryavanshi   1  8.5   294  6.1  2021
# 8     Badrinath Ki Dulhania   1  8.5   206  6.1  2017
