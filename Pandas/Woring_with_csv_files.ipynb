# %%
import pandas as pd

# %%
df = pd.read_csv("bollywood.csv")

# %%
df
# Out:
#             Actor                   Film  Year       Genre  \
# 0  Shah Rukh Khan                Pathaan  2023      Action
# 1      Aamir Khan                 Dangal  2016   Biography
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
#
#    BoxOffice (INR Crore)  IMDb  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0                   1050   7.0         NaN         NaN         NaN         NaN
# 1                   2100   8.4         NaN         NaN         NaN         NaN
# 2                    970   8.0         NaN         NaN         NaN         NaN
# 3                    586   7.6         NaN         NaN         NaN         NaN
# 4                    475   6.5         NaN         NaN         NaN         NaN
# 5                    238   7.9         NaN         NaN         NaN         NaN
# 6                    367   7.6         NaN         NaN         NaN         NaN
# 7                    294   6.1         NaN         NaN         NaN         NaN
# 8                    206   6.1         NaN         NaN         NaN         NaN

# %%
df.dropna(axis=1 , how="all",inplace=True)

# %%
df
# Out:
#             Actor                   Film  Year       Genre  \
# 0  Shah Rukh Khan                Pathaan  2023      Action
# 1      Aamir Khan                 Dangal  2016   Biography
# 2     Salman Khan      Bajrangi Bhaijaan  2015       Drama
# 3   Ranbir Kapoor                  Sanju  2018   Biography
# 4  Hrithik Roshan                    War  2019      Action
# 5   Ranveer Singh              Gully Boy  2019     Musical
# 6      Ajay Devgn                Tanhaji  2020  Historical
# 7    Akshay Kumar           Sooryavanshi  2021      Action
# 8    Varun Dhawan  Badrinath Ki Dulhania  2017     Romance
#
#    BoxOffice (INR Crore)  IMDb
# 0                   1050   7.0
# 1                   2100   8.4
# 2                    970   8.0
# 3                    586   7.6
# 4                    475   6.5
# 5                    238   7.9
# 6                    367   7.6
# 7                    294   6.1
# 8                    206   6.1

# %%
# I want that a new csv will generate and it contain only that data in which  (IMDb > 7.5)

df = df[df['IMDb'] > 7.5]

# %%
df
# Out:
#            Actor               Film  Year       Genre  BoxOffice (INR Crore)  \
# 1     Aamir Khan             Dangal  2016   Biography                   2100
# 2    Salman Khan  Bajrangi Bhaijaan  2015       Drama                    970
# 3  Ranbir Kapoor              Sanju  2018   Biography                    586
# 5  Ranveer Singh          Gully Boy  2019     Musical                    238
# 6     Ajay Devgn            Tanhaji  2020  Historical                    367
#
#    IMDb
# 1   8.4
# 2   8.0
# 3   7.6
# 5   7.9
# 6   7.6

# %%
df.to_csv("bollywood_updated.csv")

# But it also write jumbled index in my new file  -> 
# It is becaue pandas try to stop the data lose
# But you can also avoid the indexing

# %%
# Avoid Indexing file

df.to_csv("bollywood_updated_avoid.csv", index=False)

# %%
dfj = pd.read_json("Data_me.json")

# %%
dfj

# But it don't seprate the obj variable
# Out:
#               name  age  isStudent                                address
# 0  Dushyant Sharma   21       True  {'city': 'Sirsa', 'state': 'Haryana'}
# 1     Mayank Verma   20      False  {'city': 'Hisar', 'state': 'Haryana'}

# %%
# To Normalize the data use json_normalize

myData = [
  {
    "name": "Dushyant Sharma",
    "age": 21,
    "isStudent": True,
    "address": {
      "city": "Sirsa",
      "state": "Haryana"
    }
  },
  {
    "name": "Mayank Verma",
    "age": 20,
    "isStudent": False,
    "address": {
      "city": "Hisar",
      "state": "Haryana"
    }
  }
]

# %%
myData
# Out:
# [{'name': 'Dushyant Sharma',
#   'age': 21,
#   'isStudent': True,
#   'address': {'city': 'Sirsa', 'state': 'Haryana'}},
#  {'name': 'Mayank Verma',
#   'age': 20,
#   'isStudent': False,
#   'address': {'city': 'Hisar', 'state': 'Haryana'}}]

# %%
# Normalize the data

nor_json = pd.json_normalize(myData)

# %%
nor_json
# Out:
#               name  age  isStudent address.city address.state
# 0  Dushyant Sharma   21       True        Sirsa       Haryana
# 1     Mayank Verma   20      False        Hisar       Haryana

# %%
nor_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           2 non-null      object
#  1   age            2 non-null      int64
#  2   isStudent      2 non-null      bool
#  3   address.city   2 non-null      object
#  4   address.state  2 non-null      object
# dtypes: bool(1), int64(1), object(3)
# memory usage: 198.0+ bytes
